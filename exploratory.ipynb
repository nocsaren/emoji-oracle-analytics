# %%
import pandas as pd

# %%
df = pd.read_csv('./data/cleaned_data.csv')
# Out:
# C:\Users\can_s\AppData\Local\Temp\ipykernel_35964\3127445954.py:1: DtypeWarning: Columns (56,57,58,61,62,80,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/cleaned_data.csv')

# %%
# EDA settings

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# EDA variables

VERSION = '1.0.0'
COLUMNS_TO_EXPLORE = ['user_pseudo_id']

# %%
# Version filtering
df = df[df['app_version'] == '1.0.0']

# %%
df[COLUMNS_TO_EXPLORE].value_counts()
# Out:
# user_pseudo_id
# 6b53ae22a4afd334328c3909a1e4f997    20
# bbeb3a97e751dc17c7288f7f90a93a94     7
# 8c227cb3270dec78c9d6468373ebc4b0     6
# 94a94f37d9e22274206e837bd34a7dac     6
# f3cc7032f3c688cb76daae0c02827094     5
# Name: count, dtype: int64

# %%
# list all columns
print("Columns in the flattened DataFrame:")
for col in df.columns:
    print(col)
# Out:
# Columns in the flattened DataFrame:
# event_name
# event_batch_id
# user_pseudo_id
# stream_identifier
# platform
# is_active_user
# event_index_in_batch
# screen_id
# how_currency_was_earned
# session_number
# session_id
# screen_class
# engaged_session_event
# where_currency_was_earned
# currency_earned
# currency_name
# firebase_event_origin
# user_first_open_time
# user_session_count
# user_session_id
# consent_analytics_storage
# consent_ads_storage
# device_type
# mobile_brand
# mobile_model
# device_hardware_model
# operating_system
# os_version
# advertising_id
# device_language
# ad_tracking_limited
# city
# country
# continent
# region
# subcontinent
# metro_area
# app_id
# app_version
# install_store
# firebase_app_id
# app_install_source
# menu_name
# event_params__mini_game_ri
# mini_game_name
# current_tier
# character_name
# original_qi
# answered_incorrectly
# spent_on
# where_currency_was_spent
# currency_spent
# conversion_event
# previous_first_open_count
# ...

# %%
df.to_csv('./data/eda_data.csv', index=False)
