# %%
import os
import sys
import json
from datetime import timedelta

from google.cloud import bigquery
from google.oauth2 import service_account

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

from modules.pull_data import pull_and_append
from modules.flattening_json import flatten_extract_params, flatten_row, flatten_nested_column

# %%
data_path = "./data/data.json"

# project_id.dataset_id.event_YYYYMMDD
project_id = "emojioracle-342f1"
dataset_id = "analytics_481352676"

# service account key from Google Cloud IAM
bigquery_key = './keys/colab.json'
credentials = service_account.Credentials.from_service_account_file(bigquery_key)

# %%
pd.set_option('display.max_columns', None) # uncomment to see all of the cols in pandas dataframes

# %%
# will pull what is missing from BigQuery and merge into data_path
pull_and_append(credentials, project_id, dataset_id, data_path)
# Out:
# Loaded existing data.
# Latest event date in existing data: 20250410
# Fetching table: events_20250411
# Updated data.json with 32 new rows.

# %%
# load the data merged by pull_and_append into df
df = pd.read_json(data_path)

# %%
# flattenning

df = pd.DataFrame([flatten_row(row) for _, row in df.iterrows()]) # for wtfs refer to ./modules/flattening_json.py

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13294 entries, 0 to 13293
# Data columns (total 90 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   event_date                              13294 non-null  int64
#  1   event_timestamp                         13294 non-null  int64
#  2   event_name                              13294 non-null  object
#  3   event_previous_timestamp                13083 non-null  float64
#  4   event_value_in_usd                      0 non-null      float64
#  5   event_bundle_sequence_id                13294 non-null  int64
#  6   event_server_timestamp_offset           13294 non-null  int64
#  7   user_id                                 0 non-null      float64
#  8   user_pseudo_id                          13294 non-null  object
#  9   user_first_touch_timestamp              13294 non-null  int64
#  10  stream_id                               13294 non-null  int64
#  11  platform                                13294 non-null  object
#  12  is_active_user                          13294 non-null  bool
#  13  batch_event_index                       13294 non-null  int64
#  14  batch_page_id                           0 non-null      float64
#  15  batch_ordering_id                       0 non-null      float64
#  16  event_params.ga_session_id              13294 non-null  int64
#  17  event_params.firebase_screen_id         13195 non-null  float64
#  18  event_params.ga_session_number          13277 non-null  float64
#  19  event_params.ad_platform                362 non-null    object
#  20  event_params.firebase_screen_class      13195 non-null  object
#  21  event_params.ad_shown_where             362 non-null    object
#  22  event_params.ad_unit_id                 362 non-null    object
#  23  event_params.engaged_session_event      13093 non-null  float64
#  24  event_params.firebase_event_origin      13294 non-null  object
#  25  user.first_open_time                    13294 non-null  int64
#  26  user.ga_session_number                  13277 non-null  float64
#  27  user.ga_session_id                      13277 non-null  float64
#  28  privacy_info.analytics_storage          13294 non-null  object
#  29  privacy_info.ads_storage                13294 non-null  object
#  30  privacy_info.uses_transient_token       13294 non-null  object
#  31  user_ltv                                0 non-null      object
#  32  device.category                         13294 non-null  object
#  33  device.mobile_brand_name                13273 non-null  object
#  34  device.mobile_model_name                13273 non-null  object
#  35  device.mobile_marketing_name            12161 non-null  object
#  36  device.mobile_os_hardware_model         13294 non-null  object
#  37  device.operating_system                 13294 non-null  object
#  38  device.operating_system_version         13294 non-null  object
#  39  device.vendor_id                        0 non-null      object
#  40  device.advertising_id                   0 non-null      object
#  41  device.language                         13294 non-null  object
#  42  device.is_limited_ad_tracking           13294 non-null  object
#  43  device.time_zone_offset_seconds         13294 non-null  int64
#  44  device.browser                          0 non-null      object
#  45  device.browser_version                  0 non-null      object
#  46  device.web_info                         0 non-null      object
#  47  geo.city                                13294 non-null  object
#  48  geo.country                             13294 non-null  object
#  49  geo.continent                           13294 non-null  object
#  50  geo.region                              13294 non-null  object
#  51  geo.sub_continent                       13294 non-null  object
#  52  geo.metro                               13294 non-null  object
#  53  app_info.id                             13294 non-null  object
#  54  app_info.version                        13294 non-null  object
#  55  app_info.install_store                  0 non-null      object
#  56  app_info.firebase_app_id                13294 non-null  object
#  57  app_info.install_source                 13294 non-null  object
#  58  event_dimensions                        0 non-null      object
#  59  traffic_source.name                     13294 non-null  object
#  60  traffic_source.medium                   13294 non-null  object
#  61  traffic_source.source                   13294 non-null  object
#  62  ecommerce                               0 non-null      object
#  63  collected_traffic_source                0 non-null      object
#  64  event_params.update_with_analytics      0 non-null      float64
#  65  event_params.system_app_update          0 non-null      float64
#  66  event_params.firebase_conversion        2108 non-null   float64
#  67  event_params.system_app                 0 non-null      float64
#  68  event_params.previous_first_open_count  10 non-null     float64
#  69  event_params.engagement_time_msec       267 non-null    float64
#  70  event_params.time_spent                 4626 non-null   float64
#  71  event_params.menu_name                  3449 non-null   object
#  72  event_params.entrances                  63 non-null     float64
#  73  event_params.ad_network                 147 non-null    object
#  74  event_params.ad_format                  147 non-null    object
#  75  event_params.session_engaged            59 non-null     float64
#  76  event_params.current_qi                 5468 non-null   object
#  77  event_params.character_name             5468 non-null   object
#  78  event_params.current_tier               5468 non-null   object
#  79  event_params.mini_game_ri               431 non-null    object
#  80  event_params.mini_game_name             431 non-null    object
#  81  event_params.answered_wrong             561 non-null    float64
#  82  event_params.where_its_earned           2720 non-null   object
#  83  event_params.currency_name              3110 non-null   object
#  84  event_params.earned_amount              2720 non-null   float64
#  85  event_params.how_its_earned             2720 non-null   object
#  86  event_params.spent_amount               390 non-null    float64
#  87  event_params.where_its_spent            390 non-null    object
#  88  event_params.spent_to                   390 non-null    object
#  89  event_params.firebase_error             198 non-null    float64
# dtypes: bool(1), float64(23), int64(10), object(56)
# memory usage: 9.0+ MB

# %%
df.head()

# %%
df.describe(include='all')

# %%
non_null_count = df.count().sum()

print(non_null_count)

# %%
# cleaning & preprocessing

## dates and times

df['event_datetime'] = pd.to_datetime(df['event_timestamp'], unit='us', utc=True) # convert unix time to ape-friendly

df['event_date'] = df['event_datetime'].dt.date
df['event_time'] = df['event_datetime'].dt.time

df['event_previous_datetime'] = pd.to_datetime(df['event_previous_timestamp'], unit='us', utc=True)

df['event_previous_date'] = df['event_previous_datetime'].dt.date
df['event_previous_time'] = df['event_previous_datetime'].dt.time

df['event_server_delay'] = pd.to_timedelta(df['event_server_timestamp_offset'], unit='ms') # this is the time difference between the event recorded at client and the event recorded at server
df['event_server_datetime'] = df['event_datetime'] + df['event_server_delay']
